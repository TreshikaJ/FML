# %%
import numpy as np
import pandas as pd
sports={'cricket':'india','golf':'scotland','sumo':'japan','taekwondo':'south korea'}
s=pd.Series(sports)
s
# Out:
# cricket            india
# golf            scotland
# sumo               japan
# taekwondo    south korea
# dtype: object

# %%
print(s.iloc[3])
s.loc["taekwondo"]
# Out:
# south korea
# 'south korea'

# %%
sports={99:'india',100:'scotland',101:'japan',102:
        'south korea'}
s=pd.Series(sports)
s[101]
# Out:
# 'japan'

# %%
s.iloc[2]
# Out:
# 'japan'

# %% [markdown]
# Vectorization

# %%
s=pd.Series([100.0,120.0,101.0,3.0])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total=0
for item in s:
  total+=item
print(total)
# Out:
# 324.0

# %%
total=np.sum(s)
total
# Out:
# 324.0

# %%
s=pd.Series(np.random.randint(0,1000,10000))
s
# Out:
# 0        55
# 1       143
# 2        13
# 3        19
# 4       227
#        ...
# 9995    489
# 9996    857
# 9997    813
# 9998    540
# 9999    578
# Length: 10000, dtype: int64

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary=0
for item in s:
  summary+=item
# Out:
# 1.4 ms ± 66.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
np.sum(s)
# Out:
# 64 µs ± 34.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
purchase_1=pd.Series({'Name':'Chris',
                      'Item Purchased':'Milk',
                      'Cost':20}
                    )
purchase_2=pd.Series({'Name':'Christ',
                      'Item Purchased':'Mango',
                      'Cost':40}
                    )
purchase_3=pd.Series({'Name':'Rishab',
                      'Item Purchased':'Butter',
                      'Cost':50}
                    )
df=pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['Store 1','Store 2','Store 3'])
df
# Out:
#            Name Item Purchased  Cost
# Store 1   Chris           Milk    20
# Store 2  Christ          Mango    40
# Store 3  Rishab         Butter    50

# %%
print(df.loc['Store 2'])
print(df.loc['Store 2','Item Purchased'])
# Out:
# Name              Christ
# Item Purchased     Mango
# Cost                  40
# Name: Store 2, dtype: object
# Mango

# %%
df.T
# Out:
#                Store 1 Store 2 Store 3
# Name             Chris  Christ  Rishab
# Item Purchased    Milk   Mango  Butter
# Cost                20      40      50

# %%
df.loc["Store 1","Name"]="Thomas"
df["No_of_Purchases"]=[1,2,3]
df
# Out:
#            Name Item Purchased  Cost  No_of_Purchases
# Store 1  Thomas           Milk    20                1
# Store 2  Christ          Mango    40                2
# Store 3  Rishab         Butter    50                3

# %%
copy_df=df.copy()
copy_df=copy_df.drop('Store 1')
copy_df
# Out:
#            Name Item Purchased  Cost  No_of_Purchases
# Store 2  Christ          Mango    40                2
# Store 3  Rishab         Butter    50                3

# %%
df[df["Cost"]>20]
# Out:
#            Name Item Purchased  Cost  No_of_Purchases
# Store 2  Christ          Mango    40                2
# Store 3  Rishab         Butter    50                3

# %%
import pandas as pd
dict={"A":1,"B":2}
pd.DataFrame(dict,index=[0,1])
# Out:
#    A  B
# 0  1  2
# 1  1  2
